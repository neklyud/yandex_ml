# %%
import numpy as np
import pandas as pd

# %%
djia_index = pd.read_csv('djia_index.csv')

# %%
close_prices = pd.read_csv('close_prices.csv')

# %%
indexes = close_prices.iloc[:,1:]

# %%
from sklearn.decomposition import PCA
X = close_prices.iloc[:,1:]
pca = PCA(n_components = 4)
n_comp = pca.fit_transform(X)

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.73897118 0.11007169 0.04995088 0.0287492 ]

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.73897118 0.11007169 0.04995088 0.0287492 ]

# %%
pca.n_components_
# Out:
# 4

# %%
s = sum(pca.explained_variance_ratio_)
curs = 0
for item in pca.explained_variance_ratio_:
    curs += item
    if curs/s >= 0.9:
        break

# %%
print(s)
print(len(n_comp))
# Out:
# 0.9277429537836405
# 374

# %%
first_comp = [n_comp[i][0] for i in range(0,374)]

# %%
first_comp
# Out:
# [-50.902403581010745,
#  -52.846909188826025,
#  -54.61443917074285,
#  -52.60056627500216,
#  -52.37012330050848,
#  -54.65341197173623,
#  -52.812574961426,
#  -53.65114570060489,
#  -56.69272697990062,
#  -54.40265505505304,
#  -58.331645486603705,
#  -61.71626498230255,
#  -61.31940025440187,
#  -53.79252445416103,
#  -50.89263448325975,
#  -49.637407552739624,
#  -52.38761469790186,
#  -47.478542944492055,
#  -43.56033498710578,
#  -42.559280462451305,
#  -42.45027086574361,
#  -42.2712479718994,
#  -43.25272816148589,
#  -40.05934481464538,
#  -38.497263152457634,
#  -39.06492262604911,
#  -38.393043775493844,
#  -38.40055832517769,
#  -42.38616980919181,
#  -39.830574170990616,
#  -41.295486040989154,
#  -40.435549577618396,
#  -38.49607932244284,
#  -42.961580524161356,
#  -38.712521434784335,
#  -38.83379331434468,
#  -39.90606173856284,
#  -37.588245223326645,
#  -34.923567252430566,
#  -32.96232693611816,
#  -34.52461722183533,
#  -36.403459475526404,
# ...

# %%
djia_index = djia_index.iloc[:,1:]

# %%
lst = [djia_index[i][0] for i in range(0, 374)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-3dd4ad11687d> in <module>
# ----> 1 lst = [djia_index[i][0] for i in range(0, 374)]
#
# ...

# %%
lst
# Out:
# [15401.379883000001,
#  15334.589844,
#  15273.259766,
#  15328.299805,
#  15258.240234,
#  15129.669922,
#  15191.700195,
#  15133.139647999998,
#  14996.480469,
#  15072.580078,
#  14936.240234,
#  14776.530272999998,
#  14802.980469,
#  15126.070312,
#  15237.110352000002,
#  15301.259766,
#  15168.009766,
#  15373.830078,
#  15371.650391,
#  15399.650391,
#  15392.200195,
#  15467.660156,
#  15413.330078,
#  15509.209961000002,
#  15570.280272999998,
#  15568.929688,
#  15680.349609,
#  15618.759766,
#  15545.75,
#  15615.549805,
#  15639.120116999999,
#  15618.219727000002,
#  15746.879883000001,
#  15593.980469,
#  15761.780272999998,
#  15783.099609,
#  15750.669922,
#  15821.629883000001,
#  15876.219727000002,
#  15961.700195,
#  15976.019531,
#  15967.030272999998,
#  15900.820312,
#  16009.990234,
#  16064.769531,
#  16072.540038999998,
#  16072.799805,
#  16097.330078,
#  16086.410156,
#  16008.769531,
#  15914.620116999999,
#  15889.769531,
#  15821.509766,
# ...

# %%
from scipy.stats import pearsonr
print(pearsonr(first_comp,lst))
# Out:
# (0.9096522193050236, 5.192887905217981e-144)

# %%
first_comp
# Out:
# [-50.902403581010745,
#  -52.846909188826025,
#  -54.61443917074285,
#  -52.60056627500216,
#  -52.37012330050848,
#  -54.65341197173623,
#  -52.812574961426,
#  -53.65114570060489,
#  -56.69272697990062,
#  -54.40265505505304,
#  -58.331645486603705,
#  -61.71626498230255,
#  -61.31940025440187,
#  -53.79252445416103,
#  -50.89263448325975,
#  -49.637407552739624,
#  -52.38761469790186,
#  -47.478542944492055,
#  -43.56033498710578,
#  -42.559280462451305,
#  -42.45027086574361,
#  -42.2712479718994,
#  -43.25272816148589,
#  -40.05934481464538,
#  -38.497263152457634,
#  -39.06492262604911,
#  -38.393043775493844,
#  -38.40055832517769,
#  -42.38616980919181,
#  -39.830574170990616,
#  -41.295486040989154,
#  -40.435549577618396,
#  -38.49607932244284,
#  -42.961580524161356,
#  -38.712521434784335,
#  -38.83379331434468,
#  -39.90606173856284,
#  -37.588245223326645,
#  -34.923567252430566,
#  -32.96232693611816,
#  -34.52461722183533,
#  -36.403459475526404,
# ...

# %%
i = 0
for i in range(1,31):
    comp_idx = close_prices.iloc[:,i]
#    print(comp_idx, first_comp)
    print(i, pearsonr(first_comp, comp_idx))
# Out:
# 1 (0.12704705370936115, 0.013943351634603883)
# 2 (0.5551881129458611, 1.2641552124301064e-31)
# 3 (-0.2194207546990265, 1.856550852967747e-05)
# 4 (0.8578056723757195, 1.4214364075792426e-109)
# 5 (-0.6504305309751258, 2.354640824613461e-46)
# 6 (0.8927284540492069, 7.480183097659172e-131)
# 7 (0.884754847705715, 2.130363421111005e-125)
# 8 (-0.25588894400272316, 5.280111374805273e-07)
# 9 (0.8499300196224351, 1.472603410572492e-105)
# 10 (0.9614705889847026, 1.025514001571382e-210)
# 11 (-0.8122396114130519, 4.212502958053464e-89)
# 12 (0.7639624914252112, 8.994326338677356e-73)
# 13 (0.6010223050336592, 4.263950761788903e-38)
# 14 (0.673974896115656, 7.384916615752212e-51)
# 15 (0.6453569364562624, 1.9523677322364584e-45)
# 16 (-0.3278441149530383, 8.05988464957031e-11)
# 17 (0.9533450678283484, 1.3703935881171665e-195)
# 18 (0.6203385495674485, 3.769923965408403e-41)
# 19 (0.6926451353356988, 9.748398998814394e-55)
# 20 (0.930855198407259, 9.818261568148118e-165)
# ...

# %%
comp_idx = djia_index.iloc[:,0:]

# %%
close_prices.iloc[:,27]
# Out:
# 0      196.240005
# 1      193.339996
# 2      191.559998
# 3      193.559998
# 4      193.050003
#           ...
# 369    269.579987
# 370    265.029999
# 371    269.019989
# 372    264.500000
# 373    267.670013
# Name: V, Length: 374, dtype: float64

# %%
close_prices
# Out:
#            date        AXP          BA        CAT       CSCO         CVX  \
# 0    2013-09-23  76.440002  117.510002  85.029999  24.270000  125.519997
# 1    2013-09-24  76.070000  119.000000  85.110001  24.139999  124.489998
# 2    2013-09-25  75.989998  118.510002  84.500000  24.430000  124.070000
# 3    2013-09-26  76.320000  119.379997  84.199997  23.770000  123.489998
# 4    2013-09-27  75.889999  118.739998  83.800003  23.330000  122.639999
# ..          ...        ...         ...        ...        ...         ...
# 369  2015-03-12  81.559998  152.039993  80.190002  28.240000  102.419998
# 370  2015-03-13  80.599998  151.570007  79.230003  27.940001  101.620003
# 371  2015-03-16  81.500000  153.669998  79.970001  28.299999  103.129997
# 372  2015-03-17  81.059998  154.509995  78.449997  28.150000  103.169998
# 373  2015-03-18  81.860001  155.729996  81.330002  28.150000  106.699997
#
#             DD         DIS         GE          GS  ...        PFE         PG  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-df7952f0b197> in <module>
# ----> 1 pearsonr(n_comp, lst)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3408         return dtype(np.sign(x[1] - x[0])*np.sign(y[1] - y[0])), 1.0
#    3409
# -> 3410     xmean = x.mean(dtype=dtype)
#    3411     ymean = y.mean(dtype=dtype)
#    3412
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      73             is_float16_result = True
#      74
# ---> 75     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      76     if isinstance(ret, mu.ndarray):
#      77         ret = um.true_divide(
#
# TypeError: No loop matching the specified signature and casting
# was found for ufunc add
